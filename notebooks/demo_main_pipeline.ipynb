# %%
result = df.groupby("Pclass")["Fare"].mean()

spec = {
    "chart_type": "bar",
    "title": "Average Fare by Passenger Class"
}

fig = generate_plot(spec, result)

fig.show()

# %%
import plotly.express as px
from src.visualization.plotly_generator import generate_plot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import plotly.express as px
# ----> 2 from src.visualization.plotly_generator import generate_plot
#
# ModuleNotFoundError: No module named 'src'
